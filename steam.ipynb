# %%
import pandas as pd

# %%
df = pd.read_csv('steam_sales.csv')
df
# Out:
#                                               Game Name  Rating   #Reviews  \
# 0                                                  PEAK     7.0     77,683
# 1                                        Cyberpunk 2077     7.0    772,574
# 2                                                  Rust     7.0  1,038,433
# 3     Microsoft Flight Simulator (2020) 40th Anniver...     5.0     63,905
# 4                          Sid Meier's Civilization VII     4.0     34,643
# ...                                                 ...     ...        ...
# 2159            The Sims™ 4 Snowy Escape Expansion Pack     4.0      115.0
# 2160         Planet Coaster 2: Thrill-Seekers Ride Pack     4.0      136.0
# 2161                                             GORN 2     7.0      412.0
# 2162                                     Pepper Grinder     7.0      927.0
# 2163                                           Cabernet     7.0     1176.0
#
# ...

# %%
renamed_col = {
    '#Reviews' : 'num_of_review',
  
}
df = df.rename(columns = renamed_col)
df.columns
# Out:
# Index(['Game Name', 'Rating', 'num_of_review', 'Discount%', 'Price (€)',
#        'Original Price (€)', 'Release Date', 'Windows', 'Linux', 'MacOS',
#        'Fetched At'],
#       dtype='object')
